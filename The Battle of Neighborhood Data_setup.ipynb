# %%
# !pip install geopy

# %%
# !pip install folium

# %%
# !pip install geocoder

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# usage: conda-script.py [-h] [-V] command ...
# conda-script.py: error: unrecognized arguments: # uncomment this line if you haven't completed the Foursquare API lab
# usage: conda-script.py [-h] [-V] command ...
# conda-script.py: error: unrecognized arguments: # uncomment this line if you haven't completed the Foursquare API lab
# Libraries imported.

# %%
url = "https://www.mapsofindia.com/pincode/india/telangana/hyderabad/"
Hdf =pd.read_html(url,index_col=False)
Hdf=Hdf[0]
type(Hdf)
# Out:
# pandas.core.frame.DataFrame

# %%
Hdf.rename(columns={'Pincode Details': 'Location', 'Pincode Details.1': 'Pincode','Pincode Details.2': 'State', 'Pincode Details.3': 'District'}, inplace=True)

# %%
Hdf= Hdf.drop([0])

# %%
address = 'Hyderabad, TG'

geolocator = Nominatim(user_agent="Hyd_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of hyderabad are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of hyderabad are 17.38878595, 78.4610647345315.

# %%
# !pip install -U googlemaps

# %%
import geocoder
import googlemaps 
gmaps_key = googlemaps.Client(key="AIzaSyAQWqMTOcyLBRDR2skO4F_5QEWzNDOlUHw")

Hdf["LAT"]=None
Hdf["LON"]=None

for i in range(0, len(Hdf), 1):
    geocode_result = gmaps_key.geocode(Hdf.iat[i,0])
    try:
        lat = geocode_result[0]["geometry"]["location"]["lat"]
        lon = geocode_result[0]["geometry"]["location"]["lng"]
        Hdf.iat[i, Hdf.columns.get_loc("LAT")] = lat
        Hdf.iat[i, Hdf.columns.get_loc("LON")] = lon
    except:
        lat = None
        lon = None

# %%
Hdf
# Out:
#                      Location Pincode      State   District      LAT      LON
# 1                 A.G.college  500030  Telangana  Hyderabad   33.693 -117.767
# 2                 A.Gs office  500004  Telangana  Hyderabad  33.8073  -84.382
# 3        A.Gs. staff quarters  500045  Telangana  Hyderabad     None     None
# 4    Administrative Buildings  500007  Telangana  Hyderabad  35.3727 -119.015
# 5                   Afzalgunj  500012  Telangana  Hyderabad  17.3739  78.4702
# 6                     Aliabad  500015  Telangana  Hyderabad  29.0333     57.2
# 7                  Ambernagar  500044  Telangana  Hyderabad  21.7442  70.8046
# 8                    Amberpet  500013  Telangana  Hyderabad   17.392  78.5163
# 9                  Anandnagar  500004  Telangana  Hyderabad  27.1023  83.2759
# 10                 Anantagiri  501201  Telangana  Hyderabad   17.312  77.8636
# 11                  Anantaram  500015  Telangana  Hyderabad     None     None
# ...

# %%
url = "https://www.mapsofindia.com/pincode/india/karnataka/bangalore/"
Bdf =pd.read_html(url)
Bdf=Bdf[0]
type(Bdf)
# Out:
# pandas.core.frame.DataFrame

# %%
Bdf.rename(columns={'Pincode Details': 'Location', 'Pincode Details.1': 'Pincode','Pincode Details.2': 'State', 'Pincode Details.3': 'District'}, inplace=True)

# %%
Bdf= Bdf.drop([0])

# %%
Bdf
# Out:
#                            Location Pincode      State   District
# 1             A F station yelahanka  560063  Karnataka  Bangalore
# 2                           Adugodi  560030  Karnataka  Bangalore
# 3                             Agara  560034  Karnataka  Bangalore
# 4                             Agram  560007  Karnataka  Bangalore
# 5                Air Force hospital  560007  Karnataka  Bangalore
# 6                      Amruthahalli  560092  Karnataka  Bangalore
# 7                        Anandnagar  560024  Karnataka  Bangalore
# 8                            Anekal  562106  Karnataka  Bangalore
# 9                       Anekalbazar  562106  Karnataka  Bangalore
# 10                   Arabic College  560045  Karnataka  Bangalore
# 11                    Aranya Bhavan  560003  Karnataka  Bangalore
# 12                       Ashoknagar  560050  Karnataka  Bangalore
# 13                         Attibele  562107  Karnataka  Bangalore
# ...

# %%
address = 'Bangalore, KA'

geolocator = Nominatim(user_agent="Bang_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Bangalore are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Bangalore are 12.9791198, 77.5912997.

# %%
gmaps_key = googlemaps.Client(key="AIzaSyAQWqMTOcyLBRDR2skO4F_5QEWzNDOlUHw")

Bdf["LAT"]=None
Bdf["LON"]=None

for i in range(0, len(Bdf), 1):
    geocode_result = gmaps_key.geocode(Bdf.iat[i,0])
    try:
        lat = geocode_result[0]["geometry"]["location"]["lat"]
        lon = geocode_result[0]["geometry"]["location"]["lng"]
        Bdf.iat[i, Bdf.columns.get_loc("LAT")] = lat
        Bdf.iat[i, Bdf.columns.get_loc("LON")] = lon
    except:
        lat = None
        lon = None

# %%
Bdf
# Out:
#                            Location Pincode      State   District      LAT  \
# 1             A F station yelahanka  560063  Karnataka  Bangalore  13.1372
# 2                           Adugodi  560030  Karnataka  Bangalore   12.942
# 3                             Agara  560034  Karnataka  Bangalore  12.9231
# 4                             Agram  560007  Karnataka  Bangalore   45.815
# 5                Air Force hospital  560007  Karnataka  Bangalore  30.4613
# 6                      Amruthahalli  560092  Karnataka  Bangalore  13.0659
# 7                        Anandnagar  560024  Karnataka  Bangalore  27.1023
# 8                            Anekal  562106  Karnataka  Bangalore  12.7105
# 9                       Anekalbazar  562106  Karnataka  Bangalore  12.7105
# 10                   Arabic College  560045  Karnataka  Bangalore  41.7485
# 11                    Aranya Bhavan  560003  Karnataka  Bangalore  13.0105
# ...

# %%
url = "https://www.mapsofindia.com/pincode/india/maharashtra/mumbai/"
Mdf =pd.read_html(url)
Mdf=Mdf[0]
type(Mdf)
# Out:
# pandas.core.frame.DataFrame

# %%
Mdf.rename(columns={'Pincode Details': 'Location', 'Pincode Details.1': 'Pincode','Pincode Details.2': 'State', 'Pincode Details.3': 'District'}, inplace=True)

# %%
Mdf= Mdf.drop([0])

# %%
Mdf
# Out:
#                       Location Pincode        State District
# 1             A I staff colony  400029  Maharashtra   Mumbai
# 2             Aareymilk Colony  400065  Maharashtra   Mumbai
# 3                     Agripada  400011  Maharashtra   Mumbai
# 4                      Airport  400099  Maharashtra   Mumbai
# 5                     Ambewadi  400004  Maharashtra   Mumbai
# 6                      Andheri  400053  Maharashtra   Mumbai
# 7                 Andheri East  400069  Maharashtra   Mumbai
# 8      Andheri Railway station  400058  Maharashtra   Mumbai
# 9                   Antop Hill  400037  Maharashtra   Mumbai
# 10                      Asvini  400005  Maharashtra   Mumbai
# 11                  Azad Nagar  400053  Maharashtra   Mumbai
# 12                B P t colony  400003  Maharashtra   Mumbai
# 13                 B.N. bhavan  400051  Maharashtra   Mumbai
# 14                    B.P.lane  400003  Maharashtra   Mumbai
# ...

# %%
address = 'Mumbai, MH'

geolocator = Nominatim(user_agent="Mum_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Mumbai are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Mumbai are 18.9387711, 72.8353355.

# %%
gmaps_key = googlemaps.Client(key="AIzaSyAQWqMTOcyLBRDR2skO4F_5QEWzNDOlUHw")

Mdf["LAT"]=None
Mdf["LON"]=None

for i in range(0, len(Mdf), 1):
    geocode_result = gmaps_key.geocode(Mdf.iat[i,0])
    try:
        lat = geocode_result[0]["geometry"]["location"]["lat"]
        lon = geocode_result[0]["geometry"]["location"]["lng"]
        Mdf.iat[i, Mdf.columns.get_loc("LAT")] = lat
        Mdf.iat[i, Mdf.columns.get_loc("LON")] = lon
    except:
        lat = None
        lon = None

# %%
Mdf
# Out:
#                       Location Pincode        State District      LAT      LON
# 1             A I staff colony  400029  Maharashtra   Mumbai  19.0798  72.8711
# 2             Aareymilk Colony  400065  Maharashtra   Mumbai   19.151  72.8831
# 3                     Agripada  400011  Maharashtra   Mumbai  18.9777  72.8273
# 4                      Airport  400099  Maharashtra   Mumbai  32.8998 -97.0403
# 5                     Ambewadi  400004  Maharashtra   Mumbai  20.0337  72.7245
# 6                      Andheri  400053  Maharashtra   Mumbai  19.1136  72.8697
# 7                 Andheri East  400069  Maharashtra   Mumbai  19.1179  72.8631
# 8      Andheri Railway station  400058  Maharashtra   Mumbai  19.1198  72.8465
# 9                   Antop Hill  400037  Maharashtra   Mumbai  19.0283  72.8698
# 10                      Asvini  400005  Maharashtra   Mumbai  47.9925  2.73206
# 11                  Azad Nagar  400053  Maharashtra   Mumbai  19.1292   72.836
# ...
